# %%
import pandas as pd

# %%
import os

dataset_folder_path = r"io/legal_test"  # Use r for raw string to handle backslashes
dataset = [os.path.join(dataset_folder_path, entry.name) for entry in os.scandir(dataset_folder_path) if entry.is_file()]

train_folder_path = r"io/legal_train"  # Use r for raw string to handle backslashes
train = [os.path.join(train_folder_path, entry.name) for entry in os.scandir(train_folder_path) if entry.is_file()]

# %%
import json

test = {
    "question": [],
    "query": [],
    "category": []
}


for file in dataset:
    with open(file, 'r', encoding='utf-8') as f:
        data = json.load(f)
    for item in data:
        test["question"].append(item["question"])
        test["query"].append(item["query"])
        test["category"].append(file)

# %%
df_test = pd.DataFrame(test)
df_test
# Out:
#                                              question  \
# 0   Apa saja versi yang tersedia untuk Undang-Unda...
# 1   Apa saja huruf yang terdapat dalam UU No. 4 Ta...
# 2   Apa isi teks dari UU No. 17 Tahun 2012 versi 2...
# 3          Apa judul dari UU No. 11 Tahun 2014 Bab 8?
# 4   Apa jenis versi dari UU No. 49 Tahun 2008 vers...
# 5   Apa isi teks dari UU No. 26 Tahun 2007 versi 2...
# 6   Apa teks dari UU No. 11 Tahun 2010 versi 24 No...
# 7   Apa teks dari UU No. 26 Tahun 2007 Pasal 37 Ay...
# 8   UU apa saja yang dirujuk oleh UU No. 6 Tahun 2...
# 9   Apa saja sumber rujukan dari UU No. 2 Tahun 19...
# 10  Undang-undang apa saja yang merujuk ke undang-...
# 11  Undang-undang apa saja yang merujuk pada undan...
# 12  Undang-undang apa saja yang mengubah undang-un...
# 13  Undang-undang apa saja yang menghapus undang-u...
# 14  Undang-undang apa saja yang menyisipkan undang...
# 15  Undang-undang apa saja yang merujuk pada Undan...
# 16  Undang-undang apa saja yang merujuk pada Undan...
# 17  Undang-undang apa saja yang merujuk pada Undan...
# 18  Pasal apa saja yang memiliki versi 2 November ...
# 19  Pasal apa saja yang memiliki versi 6 Oktober 2...
# 20  Undang-undang apa saja yang disahkan di Jogjak...
# 21  Pasal undang-undang apa yang mengubah UU No. 3...
# 22  Undang-undang apa saja yang disahkan pada 2 Ja...
# 23  Undang-undang apa saja yang disahkan pada 29 M...
# 24  Undang-undang apa yang menghapus UU No. 13 Tah...
# 25  Undang-undang apa yang merujuk ke UU No. 8 Tah...
# 26  Undang-undang apa saja yang memiliki jenis ver...
# 27  Undang-undang apa saja yang merujuk ke UU No. ...
# 28  Undang-undang apa yang disahkan di Jakarta dan...
# 29  Undang-undang apa yang disahkan oleh DR. H. Su...
# 30  Berapa jumlah undang-undang yang merujuk ke UU...
# 31  Berapa banyak undang-undang yang dibuat pada t...
# 32  Berapa banyak pasal undang-undang yang memilik...
# 33  Berapa jumlah undang-undang yang merujuk ke UU...
# 34  Berapa banyak undang-undang yang dibuat pada t...
# 35  Berapa jumlah huruf dalam UU No. 11 Tahun 2014...
# 36  Berapa jumlah versi yang terkait dengan UU No....
# 37  Berapa jumlah bagian yang dimiliki oleh UU No....
# 38  Berapa banyak UU yang dirujuk oleh UU No. 5 Ta...
# 39  Berapa banyak ayat dalam UU No. 20 Tahun 1997 ...
#
#                                                 query  \
# 0   select ?x { <https://example.org/lex2kg/uu/197...
# 1   select ?x { <https://example.org/lex2kg/uu/201...
# 2   select ?x { <https://example.org/lex2kg/uu/201...
# 3   select ?x { <https://example.org/lex2kg/uu/201...
# 4   select ?x { <https://example.org/lex2kg/uu/200...
# 5   select ?x { <https://example.org/lex2kg/uu/200...
# 6   select ?x { <https://example.org/lex2kg/uu/201...
# 7   select ?x { <https://example.org/lex2kg/uu/200...
# 8   select ?x { <https://example.org/lex2kg/uu/201...
# 9   select ?x { <https://example.org/lex2kg/uu/198...
# 10  select ?x { ?x <https://example.org/lex2kg/ont...
# 11  select ?x { ?x <https://example.org/lex2kg/ont...
# 12  select ?x { ?x <https://example.org/lex2kg/ont...
# 13  select ?x { ?x <https://example.org/lex2kg/ont...
# 14  select ?x { ?x <https://example.org/lex2kg/ont...
# 15  select ?x { ?x <https://example.org/lex2kg/ont...
# 16  select ?x { ?x <https://example.org/lex2kg/ont...
# 17  select ?x { ?x <https://example.org/lex2kg/ont...
# 18  select ?x { ?x <https://example.org/lex2kg/ont...
# 19  select ?x { ?x <https://example.org/lex2kg/ont...
# 20  select ?x { ?x <https://example.org/lex2kg/ont...
# 21  select ?x { ?x <https://example.org/lex2kg/ont...
# 22  select ?x { ?x <https://example.org/lex2kg/ont...
# 23  select ?x { ?x <https://example.org/lex2kg/ont...
# 24  select ?x { ?x <https://example.org/lex2kg/ont...
# 25  select ?x { ?x <https://example.org/lex2kg/ont...
# 26  select ?x { ?x <https://example.org/lex2kg/ont...
# 27  select ?x { ?x <https://example.org/lex2kg/ont...
# 28  select ?x { ?x <https://example.org/lex2kg/ont...
# 29  select ?x { ?x <https://example.org/lex2kg/ont...
# 30  select (count(?x) as ?cnt) { ?x <https://examp...
# 31  select (count(?x) as ?cnt) { ?x <https://examp...
# 32  select (count(?x) as ?cnt) { ?x <https://examp...
# 33  select (count(?x) as ?cnt) { ?x <https://examp...
# 34  select (count(?x) as ?cnt) { ?x <https://examp...
# 35  select (count(?x) as ?cnt) { <https://example....
# 36  select (count(?x) as ?cnt) { <https://example....
# 37  select (count(?x) as ?cnt) { <https://example....
# 38  select (count(?x) as ?cnt) { <https://example....
# 39  select (count(?x) as ?cnt) { <https://example....
#
#                                  category
# 0   io/legal_test/simple_1_10_normal.json
# 1   io/legal_test/simple_1_10_normal.json
# 2   io/legal_test/simple_1_10_normal.json
# 3   io/legal_test/simple_1_10_normal.json
# 4   io/legal_test/simple_1_10_normal.json
# 5   io/legal_test/simple_1_10_normal.json
# 6   io/legal_test/simple_1_10_normal.json
# 7   io/legal_test/simple_1_10_normal.json
# 8   io/legal_test/simple_1_10_normal.json
# 9   io/legal_test/simple_1_10_normal.json
# 10  io/legal_test/complex_2_5_normal.json
# 11  io/legal_test/complex_2_5_normal.json
# 12  io/legal_test/complex_2_5_normal.json
# 13  io/legal_test/complex_2_5_normal.json
# 14  io/legal_test/complex_2_5_normal.json
# 15  io/legal_test/simple_2_10_normal.json
# 16  io/legal_test/simple_2_10_normal.json
# 17  io/legal_test/simple_2_10_normal.json
# 18  io/legal_test/simple_2_10_normal.json
# 19  io/legal_test/simple_2_10_normal.json
# 20  io/legal_test/simple_2_10_normal.json
# 21  io/legal_test/simple_2_10_normal.json
# 22  io/legal_test/simple_2_10_normal.json
# 23  io/legal_test/simple_2_10_normal.json
# 24  io/legal_test/simple_2_10_normal.json
# 25  io/legal_test/complex_1_5_normal.json
# 26  io/legal_test/complex_1_5_normal.json
# 27  io/legal_test/complex_1_5_normal.json
# 28  io/legal_test/complex_1_5_normal.json
# 29  io/legal_test/complex_1_5_normal.json
# 30    io/legal_test/simple_2_5_count.json
# 31    io/legal_test/simple_2_5_count.json
# 32    io/legal_test/simple_2_5_count.json
# 33    io/legal_test/simple_2_5_count.json
# 34    io/legal_test/simple_2_5_count.json
# 35    io/legal_test/simple_1_5_count.json
# 36    io/legal_test/simple_1_5_count.json
# 37    io/legal_test/simple_1_5_count.json
# 38    io/legal_test/simple_1_5_count.json
# 39    io/legal_test/simple_1_5_count.json

# %%
df_test = df_test.drop_duplicates(subset="query")
df_test
# Out:
#                                              question  \
# 0   Apa saja versi yang tersedia untuk Undang-Unda...
# 1   Apa saja huruf yang terdapat dalam UU No. 4 Ta...
# 2   Apa isi teks dari UU No. 17 Tahun 2012 versi 2...
# 3          Apa judul dari UU No. 11 Tahun 2014 Bab 8?
# 4   Apa jenis versi dari UU No. 49 Tahun 2008 vers...
# 5   Apa isi teks dari UU No. 26 Tahun 2007 versi 2...
# 6   Apa teks dari UU No. 11 Tahun 2010 versi 24 No...
# 7   Apa teks dari UU No. 26 Tahun 2007 Pasal 37 Ay...
# 8   UU apa saja yang dirujuk oleh UU No. 6 Tahun 2...
# 9   Apa saja sumber rujukan dari UU No. 2 Tahun 19...
# 10  Undang-undang apa saja yang merujuk ke undang-...
# 11  Undang-undang apa saja yang merujuk pada undan...
# 12  Undang-undang apa saja yang mengubah undang-un...
# 13  Undang-undang apa saja yang menghapus undang-u...
# 14  Undang-undang apa saja yang menyisipkan undang...
# 15  Undang-undang apa saja yang merujuk pada Undan...
# 16  Undang-undang apa saja yang merujuk pada Undan...
# 17  Undang-undang apa saja yang merujuk pada Undan...
# 18  Pasal apa saja yang memiliki versi 2 November ...
# 19  Pasal apa saja yang memiliki versi 6 Oktober 2...
# 20  Undang-undang apa saja yang disahkan di Jogjak...
# 21  Pasal undang-undang apa yang mengubah UU No. 3...
# 22  Undang-undang apa saja yang disahkan pada 2 Ja...
# 23  Undang-undang apa saja yang disahkan pada 29 M...
# 24  Undang-undang apa yang menghapus UU No. 13 Tah...
# 25  Undang-undang apa yang merujuk ke UU No. 8 Tah...
# 26  Undang-undang apa saja yang memiliki jenis ver...
# 27  Undang-undang apa saja yang merujuk ke UU No. ...
# 28  Undang-undang apa yang disahkan di Jakarta dan...
# 29  Undang-undang apa yang disahkan oleh DR. H. Su...
# 30  Berapa jumlah undang-undang yang merujuk ke UU...
# 31  Berapa banyak undang-undang yang dibuat pada t...
# 32  Berapa banyak pasal undang-undang yang memilik...
# 33  Berapa jumlah undang-undang yang merujuk ke UU...
# 34  Berapa banyak undang-undang yang dibuat pada t...
# 35  Berapa jumlah huruf dalam UU No. 11 Tahun 2014...
# 36  Berapa jumlah versi yang terkait dengan UU No....
# 37  Berapa jumlah bagian yang dimiliki oleh UU No....
# 38  Berapa banyak UU yang dirujuk oleh UU No. 5 Ta...
# 39  Berapa banyak ayat dalam UU No. 20 Tahun 1997 ...
#
#                                                 query  \
# 0   select ?x { <https://example.org/lex2kg/uu/197...
# 1   select ?x { <https://example.org/lex2kg/uu/201...
# 2   select ?x { <https://example.org/lex2kg/uu/201...
# 3   select ?x { <https://example.org/lex2kg/uu/201...
# 4   select ?x { <https://example.org/lex2kg/uu/200...
# 5   select ?x { <https://example.org/lex2kg/uu/200...
# 6   select ?x { <https://example.org/lex2kg/uu/201...
# 7   select ?x { <https://example.org/lex2kg/uu/200...
# 8   select ?x { <https://example.org/lex2kg/uu/201...
# 9   select ?x { <https://example.org/lex2kg/uu/198...
# 10  select ?x { ?x <https://example.org/lex2kg/ont...
# 11  select ?x { ?x <https://example.org/lex2kg/ont...
# 12  select ?x { ?x <https://example.org/lex2kg/ont...
# 13  select ?x { ?x <https://example.org/lex2kg/ont...
# 14  select ?x { ?x <https://example.org/lex2kg/ont...
# 15  select ?x { ?x <https://example.org/lex2kg/ont...
# 16  select ?x { ?x <https://example.org/lex2kg/ont...
# 17  select ?x { ?x <https://example.org/lex2kg/ont...
# 18  select ?x { ?x <https://example.org/lex2kg/ont...
# 19  select ?x { ?x <https://example.org/lex2kg/ont...
# 20  select ?x { ?x <https://example.org/lex2kg/ont...
# 21  select ?x { ?x <https://example.org/lex2kg/ont...
# 22  select ?x { ?x <https://example.org/lex2kg/ont...
# 23  select ?x { ?x <https://example.org/lex2kg/ont...
# 24  select ?x { ?x <https://example.org/lex2kg/ont...
# 25  select ?x { ?x <https://example.org/lex2kg/ont...
# 26  select ?x { ?x <https://example.org/lex2kg/ont...
# 27  select ?x { ?x <https://example.org/lex2kg/ont...
# 28  select ?x { ?x <https://example.org/lex2kg/ont...
# 29  select ?x { ?x <https://example.org/lex2kg/ont...
# 30  select (count(?x) as ?cnt) { ?x <https://examp...
# 31  select (count(?x) as ?cnt) { ?x <https://examp...
# 32  select (count(?x) as ?cnt) { ?x <https://examp...
# 33  select (count(?x) as ?cnt) { ?x <https://examp...
# 34  select (count(?x) as ?cnt) { ?x <https://examp...
# 35  select (count(?x) as ?cnt) { <https://example....
# 36  select (count(?x) as ?cnt) { <https://example....
# 37  select (count(?x) as ?cnt) { <https://example....
# 38  select (count(?x) as ?cnt) { <https://example....
# 39  select (count(?x) as ?cnt) { <https://example....
#
#                                  category
# 0   io/legal_test/simple_1_10_normal.json
# 1   io/legal_test/simple_1_10_normal.json
# 2   io/legal_test/simple_1_10_normal.json
# 3   io/legal_test/simple_1_10_normal.json
# 4   io/legal_test/simple_1_10_normal.json
# 5   io/legal_test/simple_1_10_normal.json
# 6   io/legal_test/simple_1_10_normal.json
# 7   io/legal_test/simple_1_10_normal.json
# 8   io/legal_test/simple_1_10_normal.json
# 9   io/legal_test/simple_1_10_normal.json
# 10  io/legal_test/complex_2_5_normal.json
# 11  io/legal_test/complex_2_5_normal.json
# 12  io/legal_test/complex_2_5_normal.json
# 13  io/legal_test/complex_2_5_normal.json
# 14  io/legal_test/complex_2_5_normal.json
# 15  io/legal_test/simple_2_10_normal.json
# 16  io/legal_test/simple_2_10_normal.json
# 17  io/legal_test/simple_2_10_normal.json
# 18  io/legal_test/simple_2_10_normal.json
# 19  io/legal_test/simple_2_10_normal.json
# 20  io/legal_test/simple_2_10_normal.json
# 21  io/legal_test/simple_2_10_normal.json
# 22  io/legal_test/simple_2_10_normal.json
# 23  io/legal_test/simple_2_10_normal.json
# 24  io/legal_test/simple_2_10_normal.json
# 25  io/legal_test/complex_1_5_normal.json
# 26  io/legal_test/complex_1_5_normal.json
# 27  io/legal_test/complex_1_5_normal.json
# 28  io/legal_test/complex_1_5_normal.json
# 29  io/legal_test/complex_1_5_normal.json
# 30    io/legal_test/simple_2_5_count.json
# 31    io/legal_test/simple_2_5_count.json
# 32    io/legal_test/simple_2_5_count.json
# 33    io/legal_test/simple_2_5_count.json
# 34    io/legal_test/simple_2_5_count.json
# 35    io/legal_test/simple_1_5_count.json
# 36    io/legal_test/simple_1_5_count.json
# 37    io/legal_test/simple_1_5_count.json
# 38    io/legal_test/simple_1_5_count.json
# 39    io/legal_test/simple_1_5_count.json

# %%
# import re

# def replace_prefix(query):
#     query = re.sub(r'<http://example.org/', 'ns1:', query)
#     query = re.sub(r'>', '', query)
#     return query

# df_test['query'] = df_test['query'].apply(replace_prefix)
# df_test
# Out:
# C:\Users\jayce\AppData\Local\Temp\ipykernel_25368\3406898892.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['query'] = df_test['query'].apply(replace_prefix)
#                                              question  \
# 0   What courses have the Digital Library & Distan...
# 1   What course has the evaluation method of Group...
# 2   What courses have 'Group Project' and 'Test' a...
# 3   What courses have the evaluation method 'Test'...
# 4   What courses have Research Methodology and Sci...
# 5   What courses have prerequisite courses that ha...
# 6   What courses have study program mandatory cour...
# 7     What courses have prerequisites with 3 credits?
# 8   What courses have prerequisites with Discrete ...
# 9   What courses have prerequisites that have test...
# 10  What is the course category of 'Spoken Languag...
# 11  What course categories does Bioinformatics bel...
# 12  What evaluation methods are associated with 'C...
# 13  What courses are prerequisites for Computer Vi...
# 14  What are the prerequisite courses for Knowledg...
# 15  What is the course category of Discrete Mathem...
# 16  How many credits does 'Introduction to Digital...
# 18  What course categories does 'Research Methodol...
# 19  What prerequisite courses does Web Application...
# 20  How many evaluation methods are associated wit...
# 21  How many prerequisite courses does 'Algorithm ...
# 22  How many courses are prerequisites for Calculu...
# 23  How many evaluation methods are associated wit...
# 24  How many evaluation methods of 'Internet of Th...
# 25  What are the courses that have 'Task' as the e...
# 26  What courses have 'Computer network' as a prer...
# 27  What are the courses that have 'Test' as their...
# 28  What courses have the category 'Study Program ...
# 29                  What courses that have 3 credits?
# 30      What course has the course code 'CSCE604222'?
# 32                  What courses that have 6 credits?
# 34  What courses have 'Programming Basics 2' as a ...
# 35  How many courses have 'Data Structures and Alg...
# 36  How many courses have Software engineering as ...
# 37  How many courses are categorized as 'Faculty M...
# 38  How many courses with 'Project Assignment' as ...
# 39  How many courses that have evaluation method '...
#
#                                                 query  \
# 0   select ?x { ?x ns1:has_research_group ns1:digi...
# 1   select ?x { ?x ns1:has_evaluation_method ns1:g...
# 2   select ?x { ?x ns1:has_evaluation_method ns1:g...
# 3   select ?x { ?x ns1:has_evaluation_method ns1:t...
# 4   select ?x { ?x ns1:has_course_category ns1:fac...
# 5   select ?x { ?x ns1:has_prerequisite_course ?y ...
# 6   select ?x { ?x ns1:has_prerequisite_course ?y ...
# 7   select ?x { ?x ns1:has_prerequisite_course ?y ...
# 8   select ?x { ?x ns1:has_prerequisite_course ?y ...
# 9   select ?x { ?x ns1:has_prerequisite_course ?y ...
# 10  select ?x { ns1:spoken_language_processing ns1...
# 11  select ?x { ns1:bioinformatics ns1:has_course_...
# 12  select ?x { ns1:cryptography_and_information_s...
# 13  select ?x { ns1:computer_vision ns1:has_prereq...
# 14  select ?x { ns1:knowledge_representation_and_r...
# 15  select ?x { ns1:discrete_mathematics_2 ns1:has...
# 16  select ?x { ns1:introduction_to_digital_system...
# 18  select ?x { ns1:research_methodology_and_scien...
# 19  select ?x { ns1:web_application_architecture n...
# 20  select (count(?x) as ?cnt) { ns1:bioinformatic...
# 21  select (count(?x) as ?cnt) { ns1:algorithm_des...
# 22  select (count(?x) as ?cnt) { ns1:calculus_2 ns...
# 23  select (count(?x) as ?cnt) { ns1:natural_langu...
# 24  select (count(?x) as ?cnt) { ns1:internet_of_t...
# 25  select ?x { ?x ns1:has_evaluation_method ns1:t...
# 26  select ?x { ?x ns1:has_prerequisite_course ns1...
# 27  select ?x { ?x ns1:has_evaluation_method ns1:t...
# 28  select ?x { ?x ns1:has_course_category ns1:stu...
# 29  select ?x { ?x ns1:has_credits '3'^^xsd:intege...
# 30  select ?x { ?x ns1:has_course_code 'CSCE604222...
# 32  select ?x { ?x ns1:has_credits '6'^^xsd:intege...
# 34  select ?x { ?x ns1:has_prerequisite_course ns1...
# 35  select (count(?x) as ?cnt) { ?x ns1:has_prereq...
# 36  select (count(?x) as ?cnt) { ?x ns1:has_prereq...
# 37  select (count(?x) as ?cnt) { ?x ns1:has_course...
# 38  select (count(?x) as ?cnt) { ?x ns1:has_evalua...
# 39  select (count(?x) as ?cnt) { ?x ns1:has_evalua...
#
#                                            category
# 0   io\courses_new_repaired\complex_1_5_normal.json
# 1   io\courses_new_repaired\complex_1_5_normal.json
# 2   io\courses_new_repaired\complex_1_5_normal.json
# 3   io\courses_new_repaired\complex_1_5_normal.json
# 4   io\courses_new_repaired\complex_1_5_normal.json
# 5   io\courses_new_repaired\complex_2_5_normal.json
# 6   io\courses_new_repaired\complex_2_5_normal.json
# 7   io\courses_new_repaired\complex_2_5_normal.json
# 8   io\courses_new_repaired\complex_2_5_normal.json
# 9   io\courses_new_repaired\complex_2_5_normal.json
# 10  io\courses_new_repaired\simple_1_10_normal.json
# 11  io\courses_new_repaired\simple_1_10_normal.json
# 12  io\courses_new_repaired\simple_1_10_normal.json
# 13  io\courses_new_repaired\simple_1_10_normal.json
# 14  io\courses_new_repaired\simple_1_10_normal.json
# 15  io\courses_new_repaired\simple_1_10_normal.json
# 16  io\courses_new_repaired\simple_1_10_normal.json
# 18  io\courses_new_repaired\simple_1_10_normal.json
# 19  io\courses_new_repaired\simple_1_10_normal.json
# 20    io\courses_new_repaired\simple_1_5_count.json
# 21    io\courses_new_repaired\simple_1_5_count.json
# 22    io\courses_new_repaired\simple_1_5_count.json
# 23    io\courses_new_repaired\simple_1_5_count.json
# 24    io\courses_new_repaired\simple_1_5_count.json
# 25  io\courses_new_repaired\simple_2_10_normal.json
# 26  io\courses_new_repaired\simple_2_10_normal.json
# 27  io\courses_new_repaired\simple_2_10_normal.json
# 28  io\courses_new_repaired\simple_2_10_normal.json
# 29  io\courses_new_repaired\simple_2_10_normal.json
# 30  io\courses_new_repaired\simple_2_10_normal.json
# 32  io\courses_new_repaired\simple_2_10_normal.json
# 34  io\courses_new_repaired\simple_2_10_normal.json
# 35    io\courses_new_repaired\simple_2_5_count.json
# 36    io\courses_new_repaired\simple_2_5_count.json
# 37    io\courses_new_repaired\simple_2_5_count.json
# 38    io\courses_new_repaired\simple_2_5_count.json
# 39    io\courses_new_repaired\simple_2_5_count.json

# %%
df_test.to_json(r"io/final_dataset/legal_test.json")

# %%
import json

train_set = {
    "question": [],
    "query": [],
    "category": []
}

for file in train:
    with open(file, 'r', encoding='utf-8') as f:
        data = json.load(f)
    for item in data:
        train_set["question"].append(item["question"])
        train_set["query"].append(item["query"])
        train_set["category"].append(file)

# %%
df_train = pd.DataFrame(train_set)
df_train
# Out:
#                                             question  \
# 0  Ada berapa banyak pasal pada UU Nomor 9 Tahun ...
# 1  Undang-undang apa saja yang merujuk pada UU No...
# 2  Undang-undang apa yang menghapus UU No. 28 Tah...
# 3       Apa isi dari UU Nomor 12 Tahun 2011 pasal 5?
# 4      Siapa yang mengesahkan UU Nomor 4 Tahun 2020?
# 5  Undang-undang apa saja yang mengubah undang-un...
# 6  Berapa jumlah undang-undang yang merujuk ke UU...
# 7  Undang-undang yang disahkan pada tanggal 26 Ok...
#
#                                                query  \
# 0  select (count(?x) AS ?jumlahPasal) { <https://...
# 1  select ?x { ?x <https://example.org/lex2kg/ont...
# 2  select ?x { ?x <https://example.org/lex2kg/ont...
# 3  select ?x { <https://example.org/lex2kg/uu/201...
# 4  select ?x { <https://example.org/lex2kg/uu/202...
# 5  select ?x { ?x lex2kg-o:mengubah ?law . ?law l...
# 6  select (count(?x) as ?cnt) { ?x <https://examp...
# 7  select ?x { ?x lex2kg-o:disahkanPada '1957-10-...
#
#                                  category
# 0    io/legal_train/simple_1_1_count.json
# 1   io/legal_train/simple_2_2_normal.json
# 2   io/legal_train/simple_2_2_normal.json
# 3   io/legal_train/simple_1_2_normal.json
# 4   io/legal_train/simple_1_2_normal.json
# 5  io/legal_train/complex_2_1_normal.json
# 6    io/legal_train/simple_2_1_count.json
# 7  io/legal_train/complex_1_1_normal.json

# %%
df_train = df_train.drop_duplicates(subset="query")
df_train
# Out:
#                                             question  \
# 0  Ada berapa banyak pasal pada UU Nomor 9 Tahun ...
# 1  Undang-undang apa saja yang merujuk pada UU No...
# 2  Undang-undang apa yang menghapus UU No. 28 Tah...
# 3       Apa isi dari UU Nomor 12 Tahun 2011 pasal 5?
# 4      Siapa yang mengesahkan UU Nomor 4 Tahun 2020?
# 5  Undang-undang apa saja yang mengubah undang-un...
# 6  Berapa jumlah undang-undang yang merujuk ke UU...
# 7  Undang-undang yang disahkan pada tanggal 26 Ok...
#
#                                                query  \
# 0  select (count(?x) AS ?jumlahPasal) { <https://...
# 1  select ?x { ?x <https://example.org/lex2kg/ont...
# 2  select ?x { ?x <https://example.org/lex2kg/ont...
# 3  select ?x { <https://example.org/lex2kg/uu/201...
# 4  select ?x { <https://example.org/lex2kg/uu/202...
# 5  select ?x { ?x lex2kg-o:mengubah ?law . ?law l...
# 6  select (count(?x) as ?cnt) { ?x <https://examp...
# 7  select ?x { ?x lex2kg-o:disahkanPada '1957-10-...
#
#                                  category
# 0    io/legal_train/simple_1_1_count.json
# 1   io/legal_train/simple_2_2_normal.json
# 2   io/legal_train/simple_2_2_normal.json
# 3   io/legal_train/simple_1_2_normal.json
# 4   io/legal_train/simple_1_2_normal.json
# 5  io/legal_train/complex_2_1_normal.json
# 6    io/legal_train/simple_2_1_count.json
# 7  io/legal_train/complex_1_1_normal.json

# %%
df_train['query'] = df_train['query'].apply(replace_prefix)
df_train
# Out:
#                                             question  \
# 0  What faculty mandatory course that have 'Test'...
# 1  What courses have prerequisites that falls und...
# 2  How many research groups does the 'Computer Sc...
# 3  What evaluation methods does Software engineer...
# 4   What evaluation methods does Deep Learning have?
# 5  How many courses have 'Programming projects an...
# 6  What courses are included in the research grou...
# 7  What courses have 'Introduction to Artificial ...
#
#                                                query  \
# 0  select ?x { ?x ns1:has_course_category ns1:fac...
# 1  select ?x { ?x ns1:has_prerequisite_course ?y ...
# 2  select (count(?x) as ?cnt) { ns1:computer_scie...
# 3  select ?x { ns1:software_engineering ns1:has_e...
# 4  select ?x { ns1:deep_learning ns1:has_evaluati...
# 5  select (count(?x) as ?cnt) { ?x ns1:has_evalua...
# 6  select ?x { ?x ns1:has_research_group ns1:reli...
# 7  select ?x { ?x ns1:has_prerequisite_course ns1...
#
#                                   category
# 0  io\courses_test\complex_1_1_normal.json
# 1  io\courses_test\complex_2_1_normal.json
# 2    io\courses_test\simple_1_1_count.json
# 3   io\courses_test\simple_1_2_normal.json
# 4   io\courses_test\simple_1_2_normal.json
# 5    io\courses_test\simple_2_1_count.json
# 6   io\courses_test\simple_2_2_normal.json
# 7   io\courses_test\simple_2_2_normal.json

# %%
df_train.to_json(r"io/final_dataset/train.json")
